# %%
import pretty_little_summary as pls
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "product": ["Widget", "Gadget", "Doohickey"],
    "price": [19.99, 29.99, 39.99],
    "quantity": [100, 50, 75]
})

result = pls.describe(df)
print(result.content)
print(result.meta)

print(pls.describe([1, 2, 3]).content)
print(pls.describe({"name": "Alice", "age": 30}).content)

arr = np.random.rand(100, 50)
result = pls.describe(arr)
print(result.content)


import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1, 2, 3], [4, 5, 6])
result = pls.describe(fig)
print(result.content)
# Out:
# A pandas DataFrame with 3 rows and 3 columns. Nulls: 0. Memory: 348.0 B. Columns: product (object, cardinality: 3 categories including 'Widget', 'Gadget', 'Doohickey'), price (float64, stats: range 20 to 40, mean 30, std 10), quantity (int64, stats: range 50 to 1e+02, mean 75, std 25). Sample row: {'product': "'Widget'", 'price': '19.99', 'quantity': '100'}.
# {'object_type': 'pandas.DataFrame', 'adapter_used': 'PandasAdapter', 'shape': (3, 3), 'columns': ['product', 'price', 'quantity'], 'dtypes': {'product': 'object', 'price': 'float64', 'quantity': 'int64'}, 'sample_data': '     product  price  quantity\n0     Widget  19.99       100\n1     Gadget  29.99        50\n2  Doohickey  39.99        75', 'metadata': {'type': 'dataframe', 'rows': 3, 'columns': 3, 'index_type': 'RangeIndex', 'index_sample': ['0', '1', '2'], 'null_count': 0, 'memory_bytes': 348, 'column_analysis': [{'name': 'product', 'dtype': 'object', 'null_count': 0, 'sample_values': ["'Widget'", "'Gadget'", "'Doohickey'"], 'cardinality': "3 categories including 'Widget', 'Gadget', 'Doohickey'", 'cardinality_sample_size': 3}, {'name': 'price', 'dtype': 'float64', 'null_count': 0, 'sample_values': ['19.99', '29.99', '39.99'], 'stats': 'range 20 to 40, mean 30, std 10', 'stats_sample_size': 3}, {'name': 'quantity', 'dtype': 'int64', 'null_count': 0, 'sample_values': ['100', '50', '75'], 'stats': 'range 50 to 1e+02, mean 75, std 25', 'stats_sample_size': 3}], 'sample_rows': [{'product': "'Widget'", 'price': '19.99', 'quantity': '100'}, {'product': "'Gadget'", 'price': '29.99', 'quantity': '50'}, {'product': "'Doohickey'", 'price': '39.99', 'quantity': '75'}]}, 'nl_summary': 'A pandas DataFrame with 3 rows and 3 columns. Nulls: 0. Memory: 348.0 B. Columns: product (object, cardinality: 3 categories including \'Widget\', \'Gadget\', \'Doohickey\'), price (float64, stats: range 20 to 40, mean 30, std 10), quantity (int64, stats: range 50 to 1e+02, mean 75, std 25). Sample row: {\'product\': "\'Widget\'", \'price\': \'19.99\', \'quantity\': \'100\'}.'}
# A list of 3 integers.
# A dict with 2 keys.
# A numpy array with shape (100, 50) and dtype float64.
# A matplotlib figure with 1 subplots.
