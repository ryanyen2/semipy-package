# %%
from semipy import semiformal, semi
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/covid_19_clean_complete.csv")
df = df.sample(100)
df.head()
# Out:
#               Province/State Country/Region        Lat       Long        Date  \
# 41780                    NaN     Bangladesh  23.685000   90.35630  2020-06-30
# 1689                     NaN         Guyana   4.860416  -58.93018  2020-01-28
# 34432  Northwest Territories         Canada  64.825500 -124.84570  2020-06-01
# 48645                    NaN        Eritrea  15.179400   39.78230  2020-07-26
# 7149                     NaN       Ethiopia   9.145000   40.48970  2020-02-18
#
#        Confirmed  Deaths  Recovered  Active       WHO Region
# 41780     145483    1847      59624   84012  South-East Asia
# 1689           0       0          0       0         Americas
# 34432          5       0          0       5         Americas
# 48645        263       0        189      74           Africa
# 7149           0       0          0       0           Africa

# %%
df['Continent'] = df['Country/Region'].apply(lambda x: semi(f'{x}s continent'))
df['Continent'].value_counts()
# Out:
# Output()
# Continent
# Asia             29
# Europe           23
# Africa           20
# North America    12
# South America    10
# Oceania           5
# Name: count, dtype: int64

# %%
df['Country'] = df['Country/Region']
df['Continent2'] = df['Country'].apply(lambda x: semi(f'{x}s continent'))
df['Continent2'].value_counts()
# Out:
# Continent2
# Asia             29
# Europe           23
# Africa           20
# North America    12
# South America    10
# Oceania           5
# Name: count, dtype: int64

# %%
df["Continent"] = semi(f"get continent from {df["Country/Region"]}")
df["Continent"].value_counts()
# Out:
# Output()
# Continent
# Asia             30
# Europe           23
# Africa           19
# North America    12
# South America    10
# Oceania           5
# Name: count, dtype: int64
