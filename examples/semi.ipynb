# %%
from semipy import semiformal, semi
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/covid_19_clean_complete.csv")
df = df.sample(100)
df.head()
# Out:
#       Province/State Country/Region        Lat        Long        Date  \
# 8140         Beijing          China  40.182400  116.414200  2020-02-22
# 48248            NaN     Uzbekistan  41.377491   64.585262  2020-07-24
# 45929            NaN    South Sudan   6.877000   31.307000  2020-07-15
# 38882            NaN    South Sudan   6.877000   31.307000  2020-06-18
# 38533   Sint Maarten    Netherlands  18.042500  -63.054800  2020-06-17
#
#        Confirmed  Deaths  Recovered  Active       WHO Region
# 8140         399       4        178     217  Western Pacific
# 48248      19360     106      10472    8782           Europe
# 45929       2153      41       1175     937           Africa
# 38882       1830      32        117    1681           Africa
# 38533         77      15         62       0           Europe

# %%
df['Country'] = df['Country/Region']
df['Continent2'] = df['Country'].apply(lambda x: semi(f'{x}s continent'))
df['Continent2'].value_counts()
# Out:
# Output()
# Continent2
# Europe           30
# Asia             19
# North America    19
# Africa           16
# South America     8
# Oceania           4
# Name: count, dtype: int64

# %%
df['Continent'] = df['Country/Region'].apply(lambda x: semi(f'{x}s continent'))
df['Continent'].value_counts()
# Out:
# Output()
# Continent
# Europe           31
# North America    19
# Asia             18
# Africa           18
# South America     8
# Oceania           4
# Name: count, dtype: int64

# %%
df["Continent"] = semi(f"get continent from {df["Country/Region"]}")
df["Continent"].value_counts()
# Out:
# Output()
# Continent
# Europe           30
# Asia             19
# North America    19
# Africa           18
# South America     8
# Oceania           4
# Name: count, dtype: int64

# %%
from IPython.display import display
import ipywidgets as ipw
import time
from rich.console import Console
from rich import get_console
console: Console = get_console()

with get_console():
    print("working")
    time.sleep(1)
    print("still working")
    time.sleep(1)
    print("done")



out = ipw.Output()
display(out)
def timeout_print_10times():
    for i in range(4):
        with out:
            print(f"Hello - {i}")
        time.sleep(1)

timeout_print_10times()
