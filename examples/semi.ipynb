# %%
from semipy import semiformal, semi
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/covid_19_clean_complete.csv")
df = df.sample(100)
df.head()

# %%
df['Continent'] = df['Country/Region'].apply(lambda x: semi(f"{semi(x)}'s continent"))
df['Continent'].value_counts()

# %%
from IPython.display import display
import ipywidgets as ipw
import time
from rich.console import Console
from rich import get_console
console: Console = get_console()

with get_console():
    print("working")
    time.sleep(1)
    print("still working")
    time.sleep(1)
    print("done")



out = ipw.Output()
display(out)
def timeout_print_10times():
    for i in range(4):
        with out:
            print(f"Hello - {i}")
        time.sleep(1)

timeout_print_10times()
