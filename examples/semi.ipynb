# %%
from semipy import semiformal, semi
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/covid_19_clean_complete.csv")
df = df.sample(100)
df.head()
# Out:
#       Province/State      Country/Region        Lat       Long        Date  \
# 11955            NaN             Tunisia  33.886917   9.537499  2020-03-07
# 23672            NaN            Portugal  39.399900  -8.224500  2020-04-21
# 4296             NaN              Greece  39.074200  21.824300  2020-02-07
# 13097            NaN               Chile -35.675100 -71.543000  2020-03-12
# 28164            NaN  West Bank and Gaza  31.952200  35.233200  2020-05-08
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 11955          1       0          0       1  Eastern Mediterranean
# 23672      21379     762        917   19700                 Europe
# 4296           0       0          0       0                 Europe
# 13097         35       0          0      35               Americas
# 28164        375       2        228     145  Eastern Mediterranean

# %%
df['Continent'] = df['Country/Region'].apply(lambda x: semi(f'{x}s continent'))
df['Continent'].value_counts()
# Out:
# Output()
# Continent
# Asia             32
# Europe           27
# Africa           16
# North America     9
# Oceania           9
# South America     4
# Name: count, dtype: int64

# %%
df["Continent"] = semi(f"get continent from {df["Country/Region"]}")
df["Continent"].value_counts()
# Out:
# Output()

# %%
from IPython.display import display
import ipywidgets as ipw
import time
from rich.console import Console
from rich import get_console
console: Console = get_console()

with get_console():
    print("working")
    time.sleep(1)
    print("still working")
    time.sleep(1)
    print("done")



out = ipw.Output()
display(out)
def timeout_print_10times():
    for i in range(4):
        with out:
            print(f"Hello - {i}")
        time.sleep(1)

timeout_print_10times()
